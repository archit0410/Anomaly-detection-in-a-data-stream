# %% [markdown]
# ### Anomaly detection in streaming data
#
#     Anomalies are data patterns that have different data characteristics from normal instances

# %% [markdown]
# ### References
# - [An Anomaly Detection Approach Based on Isolation Forest for Streaming Data Using Sliding Window (Ding & Fei, 2013)](https://www.sciencedirect.com/science/article/pii/S1474667016314999?via%3Dihub) [1]
# - [Isolation Forest (Liu, Ting, & Zhou, 2011)](https://www.researchgate.net/publication/224384174_Isolation_Forest) [2]

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\reala\appdata\roaming\python\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\reala\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\reala\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install ipympl
# Out:
# Requirement already satisfied: ipympl in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (0.9.4)
# Requirement already satisfied: ipython-genutils in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: ipython<9 in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipympl) (8.28.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (8.1.5)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (3.9.2)
# Requirement already satisfied: numpy in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (2.1.2)
# Requirement already satisfied: pillow in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from ipympl) (10.4.0)
# Requirement already satisfied: traitlets<6 in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (4.12.2)
# Requirement already satisfied: colorama in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\reala\appdata\roaming\python\python311\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\reala\appdata\roaming\python\python311\site-packages (from matplotlib<4,>=3.4.0->ipympl) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\reala\appdata\roaming\python\python311\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\reala\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\reala\appdata\roaming\python\python311\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython<9->ipympl) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\reala\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\reala\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\reala\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\reala\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (2.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install imageio[ffmpeg]
# Out:
# Requirement already satisfied: imageio[ffmpeg] in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (2.36.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from imageio[ffmpeg]) (2.1.2)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from imageio[ffmpeg]) (10.4.0)
# Requirement already satisfied: imageio-ffmpeg in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from imageio[ffmpeg]) (0.5.1)
# Requirement already satisfied: psutil in c:\users\reala\appdata\roaming\python\python311\site-packages (from imageio[ffmpeg]) (6.0.0)
# Requirement already satisfied: setuptools in c:\users\reala\appdata\local\programs\python\python311\lib\site-packages (from imageio-ffmpeg->imageio[ffmpeg]) (65.5.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from matplotlib.animation import FuncAnimation
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ### Data Generation (derived from chatgpt.com)
#
# Simulating a streaming data scenario by generating synthetic data with the following components:
#
# 1. **Regular Pattern (Sine Wave)**: This simulates a periodic pattern in the data stream, resembling real-world signals that exhibit cyclic behavior (e.g., seasonality in time series).
# 2. **Seasonal Elements**: We introduce a slower sine wave to mimic a longer-term seasonal variation that exists on top of the regular pattern.
# 3. **Random Noise**: Gaussian noise is added to simulate random variations commonly present in real-world data, making the stream more realistic and challenging for anomaly detection.
# 4. **Injected Anomalies**: Random spikes or deviations are occasionally introduced to simulate real anomalies in the data stream. These anomalies represent rare, extreme events that the iForestASD algorithm aims to detect.
#
# The `generate_data_stream` function generates the simulated data stream in real-time. It yields one data point at a time to mimic a continuous flow of data, which is ideal for testing the streaming nature of the iForestASD model.
#
# - **`num_points`**: The total number of data points to generate.
# - **`seasonality_period`**: The period of the sine wave, representing regular cyclic behavior. This can be adjusted to simulate different frequencies of regular patterns.
# - **`anomaly_rate`**: The probability of injecting an anomaly. This determines how often anomalies occur in the data stream.
# - **`noise_level`**: The standard deviation of the Gaussian noise. Higher noise levels simulate more random variation in the data, making anomaly detection more challenging.
#
# ### Continuous Data Stream:
# By using a generator function (`yield`), we simulate the continuous nature of the data stream. This allows the iForestASD model to process the data incrementally, updating its anomaly detector as new data points arrive.

# %%
# Generator function to simulate a continuous data stream
def continuous_data_stream(seasonality_period=200, anomaly_rate=0.01, noise_level=0.1):
    """
    Continuously generates a simulated data stream with regular patterns, seasonal elements, and random noise.
    
    Args:
        seasonality_period (int): The period of the seasonal component.
        anomaly_rate (float): Probability of an anomaly in the data.
        noise_level (float): The standard deviation of the noise.
    
    Yields:
        float: A single data point in the stream.
    """
    
    # Time index, continuously increasing
    t = 0
    
    while True:
        # Regular pattern (sine wave)
        regular_pattern = np.sin(2 * np.pi * t / seasonality_period)

        # Seasonal element (a slower sine wave, simulating seasonal change)
        seasonal_pattern = 0.5 * np.sin(2 * np.pi * t / (seasonality_period * 5))

        # Random noise
        noise = np.random.normal(0, noise_level)

        # Combine regular, seasonal, and noise components
        data_point = regular_pattern + seasonal_pattern + noise

        # Occasionally add anomalies (random spikes)
        if random.random() < anomaly_rate:
            data_point += random.uniform(5, 10)  # Inject an anomaly (a large spike)

        # Yield the data point to simulate continuous streaming
        yield data_point

        # Increment time index
        t += 1

# %% [markdown]
# ### Model Training
#
# We will be using the model utilized in the following paper *An Anomaly Detection Approach Based on Isolation Forest for Streaming Data Using Sliding Window (Ding & Fei, 2013)*  [[1]](https://www.sciencedirect.com/science/article/pii/S1474667016314999?via%3Dihub)
#
# ![image.png](attachment:image.png)
#
# Figure 1 : Model in use
#
# ---
#
# Before implementing this, we will first understand the original Isolation Forest model(since it is built on this paper), which is presented in *Isolation Forest (Liu, Ting, & Zhou, 2011)* [[2]](https://www.researchgate.net/publication/224384174_Isolation_Forest)
#
# #### Key Concepts:
# - Works by isolating attributes, partitioning of instances are repeated recursively until all instances are isolated
# - The algorithm builds an ensemble of of iTrees (or Isolation Trees) for a given data set.
# - For each partition it creates an iTree
# - Thus anomalies are those instances which have short average path lengths. Since : -
#     - fewer the instances of anomalies result in a smaller number of partitions thus shorter paths in tree structure
#     - instances with distinguishable attribute-values are more likely to be separated in early partitioning
#
# #### Understanding the algorithm:
# - Since recursive partitioning can be represented by a tree structure, the number of partitions required to isolate a point is equivalent
# to the path length from the root node to a terminating node
# -
#
#
# #### Why use this ?
# - iForest utilizes no distance/density measures to detect anomalies, thus eliminates major computational cost
# - Linear time complexity with a low constant & a low memory requirement
# - Has the capacity to scale up to handle extremely large data size & high-dimensional problems with a large number of irrelevant attributes
# - Has a unique way of handling the effects of swamping & masking (refer the figure 2)
# - Contrary to existing methods where large sampling size is more desirable, isolation method works best when the sampling size is kept small
#
# ![image-2.png](attachment:image-2.png)  ![image-3.png](attachment:image-3.png)
#
# Figure 2: Sub-sampling, which controls data size & helps it better isolate examples of anomalies [[2]](https://www.researchgate.net/publication/224384174_Isolation_Forest)
#
# #### Algorithm
# ![image-4.png](attachment:image-4.png)
#
# from [[1]](https://www.sciencedirect.com/science/article/pii/S1474667016314999?via%3Dihub)
#
#
# Note: We will be using the model available directly from the Scikit-learn library at "https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.IsolationForest.html" as this implementation offers a highly efficient version of the Isolation Forest algorithm, optimized for anomaly detection.
#
# Thus : -
# - `t` -> `n_estimators`
# - `ψ` -> `sample size`

# %%
model = IsolationForest(n_estimators=100, max_samples = 256,contamination='auto')
"""
sample_size = 256 # "256 generally provides enough details to perform anomaly detection across a wide range of data" [2] page 6
n_estimators = 100 # "We find that path lengths usually converge well before t = 100" [2] page 7
contamination = 'auto' # percentage of outliers in the data, 'auto' is best initially, as the model will automatically determine the percentage of outliers in the data
"""
# Out:
# '\nsample_size = 256 # "256 generally provides enough details to perform anomaly detection across a wide range of data" [2] page 6\nn_estimators = 100 # "We find that path lengths usually converge well before t = 100" [2] page 7\ncontamination = \'auto\' # percentage of outliers in the data, \'auto\' is best initially, as the model will automatically determine the percentage of outliers in the data\n'

# %%
# def iForestASD(data_stream):
#     window_size = 100
#     drift_threshold = 0.2
#     current_window = []
#     next_window = []
#     anomalies_x = []
#     anomalies_y = []

#     fig, ax = plt.subplots()
#     xdata, ydata = [], []
#     ln, = plt.plot([], [], 'b-', animated=True)
#     anomaly_points, = plt.plot([], [], 'ro', animated=True)

#     ax.set_xlim(0, 100)
#     ax.set_ylim(-3, 12)

#     def update_plot(frame):
#         global current_window, next_window, xdata, ydata, anomalies_x, anomalies_y

#         new_data = next(data_stream)
#         next_window.append(new_data)
#         xdata.append(frame)
#         ydata.append(new_data)


#         if len(next_window) == window_size:
#             next_window_reshaped = np.array(next_window).reshape(-1, 1)

#             if current_window:
#                 current_window_reshaped = np.array(current_window).reshape(-1, 1)
#                 model.fit(current_window_reshaped)  # Update the model with the current window  

#                 anomaly_scores = model.decision_function(next_window_reshaped)

#                 # Mark anomalies in the plot
#                 for i, score in enumerate(anomaly_scores):
#                     if score < 0:
#                         anomalies_x.append(xdata[-window_size + i])
#                         anomalies_y.append(ydata[-window_size + i])

#                 anomaly_rate = np.mean(anomaly_scores < 0)

#                 if anomaly_rate > drift_threshold:
#                     print(f"Drift detected at time {frame} with anomaly rate {anomaly_rate:.2f}. Retraining model...")
#                     model.fit(next_window_reshaped)

#             current_window = next_window
#             next_window = []

#         ln.set_data(xdata, ydata)
#         anomaly_points.set_data(anomalies_x, anomalies_y)

#         if len(xdata) > 100:
#             ax.set_xlim(xdata[-100], xdata[-1])

#         return ln, anomaly_points
    
#     FuncAnimation(fig, update_plot, frames=range(1000), blit=True, interval=100)
#     plt.show()

# %%
# Updated iForestASD with sliding windows and drift detection
def iForestASD(data_stream):
    window_size = 100
    drift_threshold = 0.2
    prev_window = []  # Previous window Zᵢ
    next_window = []  # Next window Zᵢ₊₁
    anomalies_x = []
    anomalies_y = []

    # Initialize IsolationForest
    model = IsolationForest(n_estimators=100, contamination=0.01)

    # Setup plot
    fig, ax = plt.subplots()
    xdata, ydata = [], []
    ln, = plt.plot([], [], 'b-', animated=True)
    anomaly_points, = plt.plot([], [], 'ro', animated=True)

    ax.set_xlim(0, 100)
    ax.set_ylim(-3, 12)

    def update_plot(frame):
        nonlocal prev_window, next_window, xdata, ydata, anomalies_x, anomalies_y

        # Get new data point from stream
        new_data = next(data_stream)
        xdata.append(frame)
        ydata.append(new_data)
        next_window.append(new_data)  # Add to next window Zᵢ₊₁

        # Ensure the window size remains fixed
        if len(next_window) == window_size:
            next_window_reshaped = np.array(next_window).reshape(-1, 1)  # Zᵢ₊₁

            # Train on the previous window (Zᵢ) and score the current window (Zᵢ₊₁)
            if prev_window:
                prev_window_reshaped = np.array(prev_window).reshape(-1, 1)

                # Train the model on Zᵢ (previous window)
                model.fit(prev_window_reshaped)

                # Score Zᵢ₊₁
                scores = model.decision_function(next_window_reshaped)

                # Mark anomalies
                for i, score in enumerate(scores):
                    if score < 0:  # Anomalies have negative scores
                        anomalies_x.append(xdata[-window_size + i])
                        anomalies_y.append(ydata[-window_size + i])

                # Calculate anomaly rate and check for drift
                anomaly_rate = np.mean(scores < 0)
                if anomaly_rate > drift_threshold:
                    print(f"Drift detected at time {frame} with anomaly rate {anomaly_rate:.2f}. Retraining model...")
                    model.fit(next_window_reshaped)

            # Move Zᵢ₊₁ to Zᵢ and start filling next window
            prev_window = next_window.copy()
            next_window = []

        # Update plot data
        ln.set_data(xdata, ydata)
        anomaly_points.set_data(anomalies_x, anomalies_y)

        # Adjust x-axis dynamically
        if len(xdata) > 100:
            ax.set_xlim(xdata[-100], xdata[-1])

        return ln, anomaly_points

    # Attach animation
    anim = FuncAnimation(fig, update_plot, frames=np.arange(0, 1000), blit=True, interval=100)
    # Save animation as HTML5 video using imageio
    video_path = "animation.mp4"
    anim.save(video_path, writer='ffmpeg')

    # Display the animation in the notebook
    html = anim.to_jshtml()
    display(HTML(html))
    plt.close()
    
# Start data stream and run the iForestASD function
iForestASD(continuous_data_stream())
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# Drift detected at time 496 with anomaly rate 0.80. Retraining model...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:223, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     222 try:
# --> 223     yield self
#     224 finally:
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1085, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1083 for anim, d in zip(all_anim, data):
#    1084     # TODO: See if turning off blit is really necessary
# -> 1085     anim._draw_next_frame(d, blit=False)
#    1086     if progress_callback is not None:
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1121, in Animation._draw_next_frame(self, framedata, blit)
#    1120 self._draw_frame(framedata)
# -> 1121 self._post_draw(framedata, blit)
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1146, in Animation._post_draw(self, framedata, blit)
#    1145 else:
# -> 1146     self._fig.canvas.draw_idle()
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1904 with self._idle_draw_cntx():
# -> 1905     self.draw(*args, **kwargs)
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3161 self.patch.draw(renderer)
# -> 3162 mimage._draw_list_compositing_images(
#    3163     renderer, self, artists, self.suppressComposite)
#    3165 renderer.close_group('figure')
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:3137, in _AxesBase.draw(self, renderer)
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1427, in Axis.draw(self, renderer)
#    1426 for tick in ticks_to_draw:
# -> 1427     tick.draw(renderer)
#    1429 # Shift label away from axes to avoid overlapping ticklabels.
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:277, in Tick.draw(self, renderer)
#     275 for artist in [self.gridline, self.tick1line, self.tick2line,
#     276                self.label1, self.label2]:
# --> 277     artist.draw(renderer)
#     278 renderer.close_group(self.__name__)
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\text.py:800, in Text.draw(self, renderer)
#     799         else:
# --> 800             textrenderer.draw_text(gc, x, y, clean_line,
#     801                                    self._fontproperties, angle,
#     802                                    ismath=ismath, mtext=mtext)
#     804 gc.restore()
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:193, in RendererAgg.draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     191 # We pass '0' for angle here, since it will be rotated (in raster
#     192 # space) in the following call to draw_text_image).
# --> 193 font.set_text(s, 0, flags=get_hinting_flag())
#     194 font.draw_glyphs_to_bitmap(
#     195     antialiased=gc.get_antialiased())
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:2543, in Image.save(self, fp, format, **params)
#    2542 try:
# -> 2543     format = EXTENSION[ext]
#    2544 except KeyError as e:
#
# KeyError: '.mp4'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 83
#      80     plt.close()
#      82 # Start data stream and run the iForestASD function
# ---> 83 iForestASD(continuous_data_stream())
#
# Cell In[14], line 75, in iForestASD(data_stream)
#      73 # Save animation as HTML5 video using imageio
#      74 video_path = "animation.mp4"
# ---> 75 anim.save(video_path, writer='ffmpeg')
#      77 # Display the animation in the notebook
#      78 html = anim.to_jshtml()
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1069, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1065 savefig_kwargs['transparent'] = False   # just to be safe!
#    1066 # canvas._is_saving = True makes the draw_event animation-starting
#    1067 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1068 # widget (both are likewise done in savefig()).
# -> 1069 with writer.saving(self._fig, filename, dpi), \
#    1070      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1071     for anim in all_anim:
#    1072         anim._init_draw()  # Clear the initial frame
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:155, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     153     value = typ()
#     154 try:
# --> 155     self.gen.throw(typ, value, traceback)
#     156 except StopIteration as exc:
#     157     # Suppress StopIteration *unless* it's the same exception that
#     158     # was passed to throw().  This prevents a StopIteration
#     159     # raised inside the "with" statement from being suppressed.
#     160     return exc is not value
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:225, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     223     yield self
#     224 finally:
# --> 225     self.finish()
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:495, in PillowWriter.finish(self)
#     494 def finish(self):
# --> 495     self._frames[0].save(
#     496         self.outfile, save_all=True, append_images=self._frames[1:],
#     497         duration=int(1000 / self.fps), loop=0)
#
# File c:\Users\reala\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:2546, in Image.save(self, fp, format, **params)
#    2544     except KeyError as e:
#    2545         msg = f"unknown file extension: {ext}"
# -> 2546         raise ValueError(msg) from e
#    2548 if format.upper() not in SAVE:
#    2549     init()
#
# ValueError: unknown file extension: .mp4

# %%
iForestASD(continuous_data_stream())
# Out:
# <div id='99257097-842f-45c3-821d-118cc9a85b51'></div>
